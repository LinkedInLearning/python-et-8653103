# %%
def say_hello():
    print("Hello, world!")

# %%
say_hello()
# Out:
# Hello, world!

# %%
def say_hello_to_person(name):
    print(f"Hello, {name}!")

# %%
say_hello_to_person("Ryan")
# Out:
# Hello, Ryan!

# %%
def get_hello_for_person(name):
    return f"Hello, {name}!"

# %%
greeting = get_hello_for_person("Ryan")

# %%
greeting
# Out:
# 'Hello, Ryan!'

# %%
greeting = say_hello_to_person("Ryan")
print(greeting)
# Out:
# Hello, Ryan!
# None

# %%
None
