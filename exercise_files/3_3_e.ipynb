# %%
from data_3_2_airport_names import data as airport_names
from data_3_2_airport_types import data as airport_types

# %%
numbers = (1, 2, 3, 4, 5)

# %%
numbers[2]
# Out:
# 3

# %%
numbers[0:3]
# Out:
# (1, 2, 3)

# %%
4 in numbers
# Out:
# True

# %%
numbers[2] = 6
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 numbers[2] = 6
#
# TypeError: 'tuple' object does not support item assignment

# %%
numbers.append(6)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 numbers.append(6)
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
letters = {"a": 1, "b": 2, "c": 3}

# %%
letters.items()
# Out:
# dict_items([('a', 1), ('b', 2), ('c', 3)])

# %%
for letter, number in letters.items():
  print(f"{letter}, {number}")
# Out:
# a, 1
# b, 2
# c, 3

# %%
one, two, three, four, five = (1, 2, 3, 4, 5)

# %%
one
# Out:
# 1

# %%
two
# Out:
# 2

# %%
three
# Out:
# 3

# %%
one, two, three, four = (1, 2, 3, 4, 5)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 one, two, three, four = (1, 2, 3, 4, 5)
#
# ValueError: too many values to unpack (expected 4)

# %%
one, two, three, four, five = [1, 2, 3, 4, 5]

# %%
one, two, three, four, five = 1, 2, 3, 4, 5

# %%
one
# Out:
# 1

# %%
two
# Out:
# 2

# %%
three
# Out:
# 3

# %%
numbers = 1, 2, 3, 4, 5

type(numbers)
# Out:
# tuple

# %%
def get_airport_name_type(code):
  return airport_names[code], airport_types[code]

# %%
bos_name, bos_type = get_airport_name_type("BOS")

# %%
bos_name
# Out:
# 'Boston Logan International Airport'

# %%
bos_type
# Out:
# 'large_airport'

# %%
bos_info = get_airport_name_type("BOS")

# %%
def get_airport_info(code):
  return {"name": airport_names[code], "type": airport_types[code]}
