# %%
city = "Carpinteria"

def say_hello():
  print(f"hello from {city}!")

say_hello()
# Out:
# hello from Carpinteria!

# %%
def define_another_city():
  another_city = "Boston"
  print(f"Another city is {another_city}")
define_another_city()
# Out:
# Another city is Boston

# %%
print(f"Another city is {another_city}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 print(f"Another city is {another_city}")
#
# NameError: name 'another_city' is not defined

# %%
def say_hello_to_la():
  city = "Los Angeles"
  print(f"Hello from {city}")

say_hello_to_la()
print(city)
# Out:
# Hello from Carpinteria
# Carpinteria

# %%
best_cities = ["Carpinteria", "Boston", "Los Angeles"]

def everything_las_vegas():
  best_cities = ["Las Vegas"] * 3
  #for i in range(0, len(best_cities)):
  #  best_cities[i] = "Las Vegas"

everything_las_vegas()

print(best_cities)
# Out:
# ['Carpinteria', 'Boston', 'Los Angeles']

# %%
["Las Vegas"] * 50
# Out:
# ['Las Vegas',
#  'Las Vegas',
#  'Las Vegas',
#  'Las Vegas',
#  'Las Vegas',
#  'Las Vegas',
#  'Las Vegas',
#  'Las Vegas',
#  'Las Vegas',
#  'Las Vegas',
#  'Las Vegas',
#  'Las Vegas',
#  'Las Vegas',
#  'Las Vegas',
#  'Las Vegas',
#  'Las Vegas',
#  'Las Vegas',
#  'Las Vegas',
#  'Las Vegas',
#  'Las Vegas',
#  'Las Vegas',
#  'Las Vegas',
#  'Las Vegas',
#  'Las Vegas',
#  'Las Vegas',
#  'Las Vegas',
#  'Las Vegas',
#  'Las Vegas',
#  'Las Vegas',
#  'Las Vegas',
#  'Las Vegas',
#  'Las Vegas',
#  'Las Vegas',
#  'Las Vegas',
#  'Las Vegas',
#  'Las Vegas',
#  'Las Vegas',
#  'Las Vegas',
#  'Las Vegas',
#  'Las Vegas',
#  'Las Vegas',
#  'Las Vegas',
#  'Las Vegas',
#  'Las Vegas',
#  'Las Vegas',
#  'Las Vegas',
#  'Las Vegas',
#  'Las Vegas',
#  'Las Vegas',
#  'Las Vegas']

# %%
city = "Los Angeles"

def move_to_boston():
  global city
  city = "Boston"

move_to_boston()
print(city)
# Out:
# Boston

# %%
city = "Los Angeles"

def move_to_boston():
  return "Boston"

city = move_to_boston()
print(city)
# Out:
# Boston
