# %%
city = "Carpinteria"

# %%
def say_hello():
	print("Hello from {city}")

# %%
def define_another_city():
    another_city = "Boston"

define_another_city()
# Out:
# Boston is the best

# %%
print(f"{another_city} is the best")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 print(f"{another_city} is the best")
#
# NameError: name 'another_city' is not defined

# %%
def define_another_city():
    another_city = "Boston"
    print(f"{another_city} is the best")

define_another_city()
# Out:
# Boston is the best

# %%
def say_hello_to_la():
    city = "Los Angeles"
    print(f"Hello from {city}!")

say_hello_to_la()
print(city)
# Out:
# Hello from Carpinteria!
# Carpinteria

# %%
best_cities = ["Boston", "Carpinteria", "Los Angeles"]

def everything_las_vegas():
    for i in range(0, len(best_cities)):
        best_cities[i] = "Las Vegas"


everything_las_vegas()

print(best_cities)
# Out:
# ['Las Vegas', 'Las Vegas', 'Las Vegas']

# %%
best_cities = ["Boston", "Carpinteria", "Los Angeles"]

def everything_las_vegas():
    best_cities = ["Las Vegas"] * 50

    print(best_cities)

everything_las_vegas()

print(best_cities)
# Out:
# ['Las Vegas', 'Las Vegas', 'Las Vegas', 'Las Vegas', 'Las Vegas', 'Las Vegas', 'Las Vegas', 'Las Vegas', 'Las Vegas', 'Las Vegas', 'Las Vegas', 'Las Vegas', 'Las Vegas', 'Las Vegas', 'Las Vegas', 'Las Vegas', 'Las Vegas', 'Las Vegas', 'Las Vegas', 'Las Vegas', 'Las Vegas', 'Las Vegas', 'Las Vegas', 'Las Vegas', 'Las Vegas', 'Las Vegas', 'Las Vegas', 'Las Vegas', 'Las Vegas', 'Las Vegas', 'Las Vegas', 'Las Vegas', 'Las Vegas', 'Las Vegas', 'Las Vegas', 'Las Vegas', 'Las Vegas', 'Las Vegas', 'Las Vegas', 'Las Vegas', 'Las Vegas', 'Las Vegas', 'Las Vegas', 'Las Vegas', 'Las Vegas', 'Las Vegas', 'Las Vegas', 'Las Vegas', 'Las Vegas', 'Las Vegas']
# ['Boston', 'Carpinteria', 'Los Angeles']

# %%
city = "Los Angeles"

def move_to_boston():
    global city
    city = "Boston"

move_to_boston()
print(city)
# Out:
# Boston

# %%
city = "Los Angeles"

def move_to_boston():
    return "Boston"

city = move_to_boston()
print(city)
# Out:
# Boston
