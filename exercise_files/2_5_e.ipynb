# %%
bool("something here")
# Out:
# True

# %%
bool(" ")
# Out:
# True

# %%
bool("")
# Out:
# False

# %%
bool([])
# Out:
# False

# %%
bool([1, 2, 3])
# Out:
# True

# %%
bool({})
# Out:
# False

# %%
bool(0)
# Out:
# False

# %%
bool(100)
# Out:
# True

# %%
bool(-1)
# Out:
# True

# %%
some_list = [1,2,3,4]

if some_list:
  print("list is non-empty")
# Out:
# list is non-empty

# %%
some_list = [1,2,3,4]

if len(some_list) == 0:
  print("list is non-empty")

# %%
bool(None)
# Out:
# False

# %%
from datetime import datetime


bool(datetime.now())
# Out:
# True

# %%
import os 

def open_file(path):
  if os.path.exists(path):
    return open(path)
  return None

# %%
file = open_file("data_2_3.py")
if file:
  print("Do something with the file")
# Out:
# Do something with the file

# %%
if (prob_of_prec > 0.5) and (temp_high > 32):
  print("Bring an umbrella!")

# %%
print(True and True)
# Out:
# True

# %%
print(False and False)
# Out:
# False

# %%
print(False and True)
# Out:
# False

# %%
print(True and False)
# Out:
# False

# %%
print(True or True)
# Out:
# True

# %%
print(False or True)
# Out:
# True

# %%
print(True or False)
# Out:
# True

# %%
print(False or False)
# Out:
# False

# %%
if (temp_high > 95) or (temp_low < 20):
  print("Stay inside today")

# %%
print(not True)
# Out:
# False

# %%
print(not False)
# Out:
# True

# %%
if is_raining and not have_umbrella:
  print("stay inside")

# %%
if not (not is_raining or have_umbrealla):
  print("Stay inside")

# %%
def is_even_number(n):
  if n % 2 == 0:
    return True
  else:
    return False

# %%
def is_even_number(n):
  return n % 2 == 0
