# %%
numbers = [0, 1, 2, 3, 4, 5]

len(numbers)
# Out:
# 6

# %%
letters = ["a", "b", "c", "d"]

# %%
a_mixed_bag = ["one", 2, 3.0, "the number that follows three", False]

# %%
len(a_mixed_bag)
# Out:
# 5

# %%
a_mixed_bag = ["one", 2, 3.0, "the number that follows three", False, [1, 2, 3]]
len(a_mixed_bag)
# Out:
# 6

# %%
for item in a_mixed_bag:
  print(item)
# Out:
# one
# 2
# 3.0
# the number that follows three
# False
# [1, 2, 3]

# %%
for letter in "a string":
  print(letter)
# Out:
# a
#
# s
# t
# r
# i
# n
# g

# %%
animals = {
  "a": "ant", 
  "b": "bear",
  "c": "cat"
}

# %%
animals["a"]
# Out:
# 'ant'

# %%
animals["b"]
# Out:
# 'bear'

# %%
animals["c"]
# Out:
# 'cat'

# %%
animals["d"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 animals["d"]
#
# KeyError: 'd'

# %%
for key in animals:
  print(key)
  print(animals[key])
# Out:
# a
# ant
# b
# bear
# c
# cat

# %%
for key in animals:
  print(f"{key} is for {animals[key]}")
# Out:
# a is for ant
# b is for bear
# c is for cat

# %%
numbers = [0, 1, 2, 3, 4, 5]

numbers[0]
# Out:
# 0

# %%
numbers[1]
# Out:
# 1

# %%
letters[0]
# Out:
# 'a'

# %%
letters[1]
# Out:
# 'b'
