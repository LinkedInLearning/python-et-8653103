# %%
from data_4_1_2023 import data

# %%
some_var = 5

# %%
type(some_var)
# Out:
# int

# %%
def some_func():
  return "Hello"

# %%
some_func()
# Out:
# 'Hello'

# %%
type(some_func)
# Out:
# function

# %%
some_func
# Out:
# <function __main__.some_func()>

# %%
some_var()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 some_var()
#
# TypeError: 'int' object is not callable

# %%
some_func.__code__.co_consts
# Out:
# (None, 'Hello')

# %%
some_func.__code__.co_code
# Out:
# b'\x95\x00g\x01'

# %%
some_other_func = some_func

# %%
some_other_func()
# Out:
# 'Hello'

# %%
5
# Out:
# 5

# %%
lambda x: x**2
# Out:
# <function __main__.<lambda>(x)>

# %%
(lambda x: x**2)(4)
# Out:
# 16

# %%
(lambda: "Hello")()
# Out:
# 'Hello'

# %%
(lambda m, n: m * n)(3, 4)
# Out:
# 12

# %%
def wrap_with_print_statements(func):
  print("About to execute function")
  print(func())
  print("Done running the function")


wrap_with_print_statements(lambda: 2 + 2)
# Out:
# About to execute function
# 4
# Done running the function

# %%
data.sort()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 data.sort()
#
# TypeError: '<' not supported between instances of 'dict' and 'dict'

# %%
numbers = [3, 1, 4, 1, 5, 9]
numbers.sort()
numbers
# Out:
# [1, 1, 3, 4, 5, 9]

# %%
data.sort(key=lambda d: d["PRCP"][0], reverse=True)

# %%
data[0]
# Out:
# {'AWND': (9.4, ',,W,'),
#  'PRCP': (3.07, ',,W,2400'),
#  'TMAX': (86.0, ',,W,2400'),
#  'TMIN': (64.0, ',,W,2400'),
#  'date': '2023-07-29'}
