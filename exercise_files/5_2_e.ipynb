# %%
some_var = 5

# %%
type(some_var)
# Out:
# int

# %%
def some_func():
	return "Hello!"

some_func()
# Out:
# 'Hello!'

# %%
type(some_func)
# Out:
# function

# %%
some_func()
# Out:
# 'Hello!'

# %%
some_func
# Out:
# <function __main__.some_func()>

# %%
some_var
# Out:
# 5

# %%
some_var()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 some_var()
#
# TypeError: 'int' object is not callable

# %%
import inspect

print(inspect.getsource(some_func))
# Out:
# def some_func():
# 	return "Hello!"

# %%
some_func.__code__.co_code
# Out:
# b'\x97\x00y\x01'

# %%
some_func.__code__.co_consts
# Out:
# (None, 'Hello!')

# %%
type(some_func.__code__.co_code)
# Out:
# bytes

# %%
some_other_func = some_func

# %%
some_other_func()
# Out:
# 'Hello!'

# %%
5
# Out:
# 5

# %%
lambda x: x**2
# Out:
# <function __main__.<lambda>(x)>

# %%
(lambda x: x**2)(4)
# Out:
# 16

# %%
(lambda: "Hello")()
# Out:
# 'Hello'

# %%
(lambda m, n: m * n)(3, 4)
# Out:
# 12

# %%
def wrap_with_print_statements(func):
    print("About to execute the function")
    print(func())
    print("Done running the function!")


wrap_with_print_statements(lambda: 2 + 2)
# Out:
# About to execute the function
# 4
# Done running the function!

# %%
from data_4_1_2025 import data

# %%
data.sort()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 data.sort()
#
# TypeError: '<' not supported between instances of 'dict' and 'dict'

# %%
numbers = [3, 1, 4, 1, 5, 9]
numbers.sort()
numbers
# Out:
# [1, 1, 3, 4, 5, 9]

# %%
numbers.sort(lambda n: -n)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 numbers.sort(lambda n: -n)
#
# TypeError: sort() takes no positional arguments

# %%
data.sort(key=lambda d: d['PRCP'], reverse=True)

# %%
for d in data[0:10]:
    print(d)
# Out:
# {'AWND': (20.8, ',,W,'), 'PRCP': (3.11, ',,W,2400'), 'TMAX': (48.0, ',,W,2400'), 'TMIN': (45.0, ',,W,2400'), 'date': '2025-05-22'}
# {'AWND': (12.3, ',,W,'), 'PRCP': (1.77, ',,W,2400'), 'TMAX': (61.0, ',,W,2400'), 'TMIN': (41.0, ',,W,2400'), 'date': '2025-03-17'}
# {'AWND': (23.7, ',,1,'), 'PRCP': (1.67, ',,1,2400'), 'TMAX': (56.0, ',,1,2400'), 'TMIN': (52.0, ',,1,2400'), 'date': '2025-10-13'}
# {'AWND': (16.8, ',,W,'), 'PRCP': (1.49, ',,W,2400'), 'TMAX': (37.0, ',,W,2400'), 'TMIN': (26.0, ',,W,2400'), 'date': '2025-02-16'}
# {'AWND': (9.4, ',,1,'), 'PRCP': (1.42, ',,1,2400'), 'TMAX': (72.0, ',,1,2400'), 'TMIN': (63.0, ',,1,2400'), 'date': '2025-09-25'}
# {'AWND': (7.8, ',,W,'), 'PRCP': (1.33, ',,W,2400'), 'TMAX': (67.0, ',,W,2400'), 'TMIN': (63.0, ',,W,2400'), 'date': '2025-07-10'}
# {'AWND': (14.8, ',,W,'), 'PRCP': (1.09, ',,W,2400'), 'TMAX': (56.0, ',,W,2400'), 'TMIN': (48.0, ',,W,2400'), 'date': '2025-05-09'}
# ...
