# %% [markdown]
# ## Exceptions

# %%
some_var
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 some_var
#
# NameError: name 'some_var' is not defined

# %%
raise NameError("Just feel like causing a fuss")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 raise NameError("Just feel like causing a fuss")
#
# NameError: Just feel like causing a fuss

# %%
def add_ints(num1, num2):
    if not isinstance(num1, int) or not isinstance(num2, int):
        raise Warning(f"Can only add ints")
    return num1 + num2

# %%
add_ints(3.1, 2)
print("Function ran successfully!")
# Out:
# ---------------------------------------------------------------------------
# Warning                                   Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 add_ints(3.1, 2)
#       2 print("Function ran successfully!")
#
# Cell In[10], line 3, in add_ints(num1, num2)
#       1 def add_ints(num1, num2):
#       2     if not isinstance(num1, int) or not isinstance(num2, int):
# ----> 3         raise Warning(f"Can only add ints")
#       4     return num1 + num2
#
# ...

# %%
def iterate_through_list():
    for i in range(0, 3):
        yield i

generator = iterate_through_list()

# %%
next(generator)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 next(generator)
#
# StopIteration:

# %%
for i in generator:
    print(i)
# Out:
# 0
# 1
# 2

# %%
try:
    print(next(generator))
except:
    print("Ran out of stuff")
# Out:
# Ran out of stuff

# %%
def do_math():
    return 1/0


do_math()
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[76], line 5
#       1 def do_math():
#       2     return 1/0
# ----> 5 do_math()
#
# Cell In[76], line 2, in do_math()
#       1 def do_math():
# ----> 2     return 1/0
#
# ZeroDivisionError: division by zero

# %%
def do_math():
    return 1/0

def store_math_success_in_database():
    pass

try:
    print("About to do math")
    do_math()
    store_math_success_in_database()
except:
    print("Whoops!")

print("This always runs")
# Out:
# About to do math
# Whoops!
# This always runs

# %%
def do_math():
    return 1/0


try:
    print("About to do math")
    do_math()
except:
    print("Whoops!")
else:
    store_math_success_in_database()

print("This always runs")
# Out:
# About to do math
# Whoops!
# This always runs

# %%
    #return 2.0 ** 10000

# %%
def do_math():
    #return 2.0 ** 10000
    return 1/0

try:
    print("About to do math")
    do_math()

except ZeroDivisionError:
    print("Can't divide by zero!")
except OverflowError:
    print("Too big!")
# Out:
# About to do math
# Can't divide by zero!

# %%
def do_math():
    some_var
    #return 2.0 ** 10000
    return 1/0
    

try:
    print("About to do math")
    do_math()
except ArithmeticError:
    print("Some bad math happened!")

print("This always runs")
# Out:
# About to do math
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[85], line 9
#       7 try:
#       8     print("About to do math")
# ----> 9     do_math()
#      10 except ArithmeticError:
#      11     print("Some bad math happened!")
#
# Cell In[85], line 2, in do_math()
#       1 def do_math():
# ----> 2     some_var
#       3     #return 2.0 ** 10000
#       4     return 1/0
#
# NameError: name 'some_var' is not defined

# %%
def do_math():
    some_var
    #return 2.0 ** 10000
    return 1/0

def never_quit():
    while True:
        pass

try:
    never_quit()
except ArithmeticError:
    print("Some bad math happened!")
except Exception:
    print("Something else bad happened!")

print("This always runs")
# Out:
# About to do math
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[87], line 12
#      10 try:
#      11     print("About to do math")
# ---> 12     never_quit()()
#      13 except ArithmeticError:
#      14     print("Some bad math happened!")
#
# Cell In[87], line 7, in never_quit()
#       6 def never_quit():
# ----> 7     while True:
#       8         pass
#
# KeyboardInterrupt:

# %%
def do_data_processing_batch(i):
    pass
    
for i in range(0, 100):
    try:
        do_data_processing_batch(i)
    except Exception:
        print("Failed to process batch {i}, continuing on")

# %%
def never_quit():
    while True:
        pass
    

never_quit()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 6
#       2     while True:
#       3         pass
# ----> 6 never_quit()
#
# Cell In[2], line 2, in never_quit()
#       1 def never_quit():
# ----> 2     while True:
#       3         pass
#
# KeyboardInterrupt:
