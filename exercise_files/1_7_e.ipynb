# %%
date = "2025-07-02T00:00:00"

# %%
date.split("T")
# Out:
# ['2025-07-02', '00:00:00']

# %%
date_parts = split(date, "T")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 date_parts = split(date, "T")
#
# NameError: name 'split' is not defined

# %%
date_parts = date.split("T")

# %%
class Date:
    def __init__(self, month, day, year):
        self.month = month
        self.day = day
        self.year = year

# %%
birthday = Date(2, 20, 1991)

# %%
birthday.month
# Out:
# 2

# %%
birthday.year
# Out:
# 1991

# %%
class Date:
    def __init__(self, month, day, year):
        self.month = month
        self.day = day
        self.year = year


    def get_formatted_string(self):
        return f"{self.month} {self.day}, {self.year}"

# %%
birthday = Date(2, 20, 1991)

birthday.get_formatted_string()
# Out:
# '2 20, 1991'

# %%
import calendar
