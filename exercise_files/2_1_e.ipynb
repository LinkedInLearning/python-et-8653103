# %%
x = 5

# %%
y = 5.0

# %%
int(y)
# Out:
# 5

# %%
int(5.3)
# Out:
# 5

# %%
int(5.9999999999999)
# Out:
# 5

# %%
round(5.9999999999)
# Out:
# 6

# %%
round(5.123445, 2)
# Out:
# 5.12

# %%
5 * 4
# Out:
# 20

# %%
5 * 4.5
# Out:
# 22.5

# %%
5 * 4.0
# Out:
# 20.0

# %%
5 * 4 * 7 * 1.0
# Out:
# 140.0

# %%
5 ** 2
# Out:
# 25

# %%
5 ** 2.0
# Out:
# 25.0

# %%
1/3
# Out:
# 0.3333333333333333

# %%
5/1
# Out:
# 5.0

# %%
int(5/1)
# Out:
# 5

# %%
5//1
# Out:
# 5

# %%
100//51
# Out:
# 1

# %%
round(100/51)
# Out:
# 2

# %%
14 % 10
# Out:
# 4

# %%
1000005 % 10
# Out:
# 5

# %%
n = 36

if n % 3 == 0:
  print("Divisible by 3!")
# Out:
# Divisible by 3!

# %%
# Jan 1 = Monday

# What day of the week is Jan 25?

25 % 7
# Out:
# 4

# %%
1 + 1
# Out:
# 2

# %%
5 - 3
# Out:
# 2

# %%
1 + 1.0
# Out:
# 2.0

# %%
1.2 - 1.1
# Out:
# 0.09999999999999987
