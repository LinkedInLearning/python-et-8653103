# %%
from datetime import datetime

# %%
def some_function(arg1, arg2):
  pass

# %%
some_function(1, 6)

# %%
def repeat_string(string_to_repeat: str, times_to_repeat: int) -> str:
  return string_to_repeat * times_to_repeat

# %%
repeat_string("echo!", 10)
# Out:
# 'echo!echo!echo!echo!echo!echo!echo!echo!echo!echo!'

# %%
def get_noaa_weather_data(station_code: str, start_date: datetime, end_date: datetime, measurement_types: list[str]) -> list[dict]:

  """
  Retrieves data from the NOAA API: <url here>
  Station codes can be found at: <url here>
  Available measurement types:
  AWND = Average daily wind speed (mph)
  PRCP = Precipitation (inches)
  SNOW = Snowfall (inches)
  SNWD = Snow depth (inches)
  TMAX = Maximum temperature (degrees F)
  TMIN = Minimum temperature (degrees F)
  """

# %%
5
# Out:
# 5

# %%
alphabet = {
  "a": "apple",
  "b": "bear",
  # consider changing to camel
  "c": "cat"
}

# %%
alphabet = {
  "a": "apple",
  "b": "bear",
  """
  consider changing key to "c"
  """
  42: "cat"
}
# Out:
#   Cell In[20], line 4
#     """
#       ^
# SyntaxError: ':' expected after dictionary key

# %%
alphabet
# Out:
# {'a': 'apple', 'b': 'bear', '\n  consider changing to camel\n  c': 'cat'}

# %%
def sum_of_squares(n1: int, n2: int) -> int | None:
  """
  Return the sum of squares of two integers
  """
  if isinstance(n1, int) and isinstance(n2, int):
    return n1 ** 2 + n2 ** 2
  return

# %%
sum_of_squares(4, 5)
# Out:
# 41

# %%
sum_of_squares("hello", "world")

# %%
def get_some_squares(n1: int, n2: int) -> tuple[int, int]:
  return n1**2, n2**2
